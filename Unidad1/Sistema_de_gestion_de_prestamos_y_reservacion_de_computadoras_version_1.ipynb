# %% [markdown]
# <a href="https://colab.research.google.com/github/danieldelgado172/FundamentosProgramacion/blob/main/Unidad1/Sistema_de_gestion_de_prestamos_y_reservacion_de_computadoras_version_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Ingenieria en sistemas computacionales 1**
# ##**Fundamentos de programacion**
# ##**Unidad1**
# ##*Sistema de gestion de prestamos y reservacion de computadoras version 1*
#
# Docente: **José Gabriel Rodríguez Rivas**
#
# Alumno: Daniel Abiasaf Delgado Torres

# %%
alumnos=["26040200", "26040201", "26040202", "26040203", "26040204"]
computadoras=["PC-LC1-01", "PC-LC1-02", "PC-LC1-03",
              "PC-LC2-01", "PC-LC2-02", "PC-LC2-03",
              "PC-LC3-01", "PC-LC3-02", "PC-LC3-03", "PC-LC3-04"]
aulas=["LC1", "LC1", "LC1",
       "LC2", "LC2", "LC2",
       "LC3", "LC3", "LC3", "LC3",]
sofware=["Python, VS code", "Python, Java, VS code", "Autocad, Mathlab",
         "Python, VS code", "Python, Java, VS code", "Autocad, Mathlab",
         "Python, VS code", "Python, Java, VS code", "Autocad, Mathlab", "Python, VS code", ]
Estados=["Disponible", "Prestada", "Reservada",
         "Disponible", "Prestada", "Reservada",
         "Disponible", "Prestada", "Reservada", "Mantenimiento"]
opcion=0
while opcion==0:
  print("+==========================+")
  print("|   Sistema de prestamos   |")
  print("+==========================+")
  print("| 1.Consultar computadoras |")
  print("| 2.Buscar por sofware     |")
  print("| 3.Solicitar prestamo     |")
  print("| 4.Devolver computadora   |")
  print("| 5.Crear reservacion      |")
  print("| 6.Agregar computadora    |")
  print("| 7.Salir                  |")
  print("+==========================+")
  opcion=int(input("Seleccione una opcion "))
  if(opcion==1):
    print("\n---Computadoras---")
    for i in range(len(computadoras)):
      print("Aulas: ", aulas[i], "  ID: ", computadoras[i], "  Sofware: ", sofware[i], "  Estado: ", Estados[i])
      print("-----------------------------")
  elif(opcion==2):
    for i in range(len(sofware)):
      print(i)
# Out:
# +==========================+
# |   Sistema de prestamos   |
# +==========================+
# | 1.Consultar computadoras |
# | 2.Buscar por sofware     |
# | 3.Solicitar prestamo     |
# | 4.Devolver computadora   |
# | 5.Crear reservacion      |
# | 6.Agregar computadora    |
# | 7.Salir                  |
# +==========================+
# Seleccione una opcion 1
#
# ---Computadoras---
# Aulas:  LC1   ID:  PC-LC1-01   Sofware:  Python, VS code   Estado:  Disponible
# -----------------------------
# Aulas:  LC1   ID:  PC-LC1-02   Sofware:  Python, Java, VS code   Estado:  Prestada
# -----------------------------
# Aulas:  LC1   ID:  PC-LC1-03   Sofware:  Autocad, Mathlab   Estado:  Reservada
# -----------------------------
# Aulas:  LC2   ID:  PC-LC2-01   Sofware:  Python, VS code   Estado:  Disponible
# -----------------------------
# Aulas:  LC2   ID:  PC-LC2-02   Sofware:  Python, Java, VS code   Estado:  Prestada
# -----------------------------
# ...

# %%
opcion=0
while opcion<=6:
  print("1.Consultar computadoras")
  print("2.Buscar por sofware")
  print("3.Solicitar prestamo")
  print("4.Devolver computadora")
  print("5.Crear reservacion")
  print("6.Agregar computadora")
  print("7.Salir")
  opcion=int(input("Ingresa una opcion "))
  if(opcion==1):
    print("lista de computadoras")
  elif(opcion==2):
    print("Lista de sofware")
  elif(opcion==3):
    print("Solicitar prestamo")
  elif(opcion==4):
    print("Computadora devuelta")
  elif(opcion==5):
    print("Reservacion hecha")
  elif(opcion==6):
    print("Computadora agregada")
  elif(opcion==7):
    print("Saliste")
# Out:
# 1.Consultar computadoras
# 2.Buscar por sofware
# 3.Solicitar prestamo
# 4.Devolver computadora
# 5.Crear reservacion
# 6.Agregar computadora
# 7.Salir
# Ingresa una opcion 1
# lista de computadoras
# 1.Consultar computadoras
# 2.Buscar por sofware
# 3.Solicitar prestamo
# 4.Devolver computadora
# 5.Crear reservacion
# 6.Agregar computadora
# 7.Salir
# Ingresa una opcion 2
# Lista de sofware
# 1.Consultar computadoras
# 2.Buscar por sofware
# 3.Solicitar prestamo
# 4.Devolver computadora
# 5.Crear reservacion
# 6.Agregar computadora
# 7.Salir
# Ingresa una opcion 3
# Solicitar prestamo
# 1.Consultar computadoras
# 2.Buscar por sofware
# 3.Solicitar prestamo
# 4.Devolver computadora
# 5.Crear reservacion
# 6.Agregar computadora
# 7.Salir
# Ingresa una opcion 4
# Computadora devuelta
# 1.Consultar computadoras
# 2.Buscar por sofware
# 3.Solicitar prestamo
# 4.Devolver computadora
# 5.Crear reservacion
# 6.Agregar computadora
# 7.Salir
# Ingresa una opcion 5
# Reservacion hecha
# ...
