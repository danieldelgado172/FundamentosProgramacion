# %% [markdown]
# <a href="https://colab.research.google.com/github/danieldelgado172/FundamentosProgramacion/blob/main/Python1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
X=5
X="Hola mundo"
X=True
print("el valor de x es:", X);
# Out:
# 2
